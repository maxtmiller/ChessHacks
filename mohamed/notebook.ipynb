# %%
# !git clone https://github.com/maxtmiller/ChessHacks.git
# !pip install chess -q
# !pip install gdown -q
# !pip install mlflow -q
# %cd ChessHacks/mohamed
# Out:
# Cloning into 'ChessHacks'...
# remote: Enumerating objects: 681, done.
# remote: Counting objects: 100% (681/681), done.
# remote: Compressing objects: 100% (641/641), done.
# remote: Total 681 (delta 30), reused 669 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (681/681), 30.31 MiB | 28.74 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 50.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
# /kaggle/working/ChessHacks/mohamed

# %%
# !gdown https://drive.google.com/uc?id=1XS43DddEqNruDCmCBIzd0CKIrXEXQADq
# !gdown https://drive.google.com/uc?id=1amh4YfqE7_HZ3VA4S2XroR-Rgn5W4qT_
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1XS43DddEqNruDCmCBIzd0CKIrXEXQADq
# From (redirected): https://drive.google.com/uc?id=1XS43DddEqNruDCmCBIzd0CKIrXEXQADq&confirm=t&uuid=8e92c93d-66c2-4189-b6de-f337e2024024
# To: /kaggle/working/ChessHacks/mohamed/X.pt
# 100%|███████████████████████████████████████| 13.9G/13.9G [00:48<00:00, 287MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1amh4YfqE7_HZ3VA4S2XroR-Rgn5W4qT_
# From (redirected): https://drive.google.com/uc?id=1amh4YfqE7_HZ3VA4S2XroR-Rgn5W4qT_&confirm=t&uuid=e6d5bbce-ada0-4162-b708-3b6c00d8bdc6
# To: /kaggle/working/ChessHacks/mohamed/y.pt
# 100%|███████████████████████████████████████| 33.4M/33.4M [00:00<00:00, 230MB/s]

# %%
# !python training.py --epochs 20 --batch_size 256
# Out:
# Training samples: 3340710, Validation samples: 835178
# Model initialized.
# Epoch 1/10:  86%|████████████████████▋   | 44995/52199 [05:39<00:53, 134.72it/s]
